# %% [markdown]
# <a href="https://colab.research.google.com/github/linamendezh7/EjerciciosBIT-LinaMendez/blob/DataScience/Actividad_3_Manejo_de_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Actividad 3  : Manejo de pandas
# Subir un Jupyter Notebook (archivo con extension ipynb) al repositorio de github con las siguientes especificaciones:
#
# Leer un archivo del formato de su elección sobre cualquier temática

# %%
import pandas as pd
import numpy as np
print(f"Versión de Pandas: {pd.__version__}")
# Out:
# Versión de Pandas: 2.2.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Muestre la forma (SHAPE), información general (df.info()) y estadisticas descriptivas (df.describe()) del dataset

# %%
proyecto =pd.read_csv("/content/drive/MyDrive/Bootcamp/Proyecto.csv")
proyecto.head(5)
# Out:
#    Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 0   29  Female     Artist          6.0                           2.7
# 1   46   Other      Nurse          6.2                           5.7
# 2   64    Male      Other          5.0                           3.7
# 3   20  Female  Scientist          5.8                           2.8
# 4   49  Female      Other          8.2                           2.3
#
#    Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 0                       181                                 10     Yes
# 1                       200                                  8     Yes
# 2                       117                                  4      No
# 3                       360                                  6     Yes
# 4                       247                                  4     Yes
#
#   Family History of Anxiety  Stress Level (1-10)  Heart Rate (bpm)  \
# ...

# %%
proyecto.shape
# Out:
# (11000, 19)

# %%
proyecto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                11000 non-null  int64
#  1   Gender                             11000 non-null  object
#  2   Occupation                         11000 non-null  object
#  3   Sleep Hours                        11000 non-null  float64
#  4   Physical Activity (hrs/week)       11000 non-null  float64
#  5   Caffeine Intake (mg/day)           11000 non-null  int64
#  6   Alcohol Consumption (drinks/week)  11000 non-null  int64
#  7   Smoking                            11000 non-null  object
#  8   Family History of Anxiety          11000 non-null  object
#  9   Stress Level (1-10)                11000 non-null  int64
#  10  Heart Rate (bpm)                   11000 non-null  int64
# ...

# %%
proyecto.describe()
# Out:
#                 Age   Sleep Hours  Physical Activity (hrs/week)  \
# count  11000.000000  11000.000000                  11000.000000
# mean      40.241727      6.650691                      2.942136
# std       13.236140      1.227509                      1.827825
# min       18.000000      2.300000                      0.000000
# 25%       29.000000      5.900000                      1.500000
# 50%       40.000000      6.700000                      2.800000
# 75%       51.000000      7.500000                      4.200000
# max       64.000000     11.300000                     10.100000
#
#        Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week)  \
# count              11000.000000                       11000.000000
# mean                 286.090000                           9.701636
# std                  144.813157                           5.689713
# min                    0.000000                           0.000000
# ...

# %%
proyecto.tail(1)
# Out:
#        Age Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 10999   56  Other    Teacher          6.1                           1.1
#
#        Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 10999                       205                                 11      No
#
#       Family History of Anxiety  Stress Level (1-10)  Heart Rate (bpm)  \
# 10999                        No                    1                66
#
#        Breathing Rate (breaths/min)  Sweating Level (1-5) Dizziness  \
# 10999                            13                     3        No
#
#       Medication  Therapy Sessions (per month) Recent Major Life Event  \
# 10999         No                             2                     Yes
#
#        Diet Quality (1-10)  Anxiety Level (1-10)
# 10999                    8                   2.0

# %% [markdown]
# Genere un nuevo dataset aplicando un filtro sobre los datos originales
# Genere un nuevo dataset aplicando un ordenamiento sobre los datos originales

# %%
Stress_level_high = proyecto[proyecto["Stress Level (1-10)"]>9]

# %%
Proy =Stress_level_high.rename(columns={"Stress Level (1-10)":"Stress level"})
Proy.head(5)
# Out:
#     Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 0    29  Female     Artist          6.0                           2.7
# 12   45   Other    Teacher          7.9                           0.1
# 26   49   Other     Doctor          6.0                           3.8
# 46   53   Other     Doctor          5.9                           1.6
# 47   35   Other    Athlete          5.0                           0.5
#
#     Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 0                        181                                 10     Yes
# 12                       128                                  2      No
# 26                       357                                 13      No
# 46                       443                                  9     Yes
# 47                       533                                  6     Yes
#
#    Family History of Anxiety  Stress level  Heart Rate (bpm)  \
# ...

# %%
Proy.sort_values(by="Sleep Hours").head(2)
# Out:
#       Age  Gender Occupation  Sleep Hours  Physical Activity (hrs/week)  \
# 7465   31  Female       Chef          2.3                           2.0
# 906    32  Female     Artist          2.5                           0.4
#
#       Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week) Smoking  \
# 7465                       518                                  6     Yes
# 906                        575                                  6     Yes
#
#      Family History of Anxiety  Stress level  Heart Rate (bpm)  \
# 7465                       Yes            10               115
# 906                        Yes            10                98
#
#       Breathing Rate (breaths/min)  Sweating Level (1-5) Dizziness Medication  \
# 7465                            24                     3       Yes        Yes
# 906                             21                     4        No        Yes
#
#       Therapy Sessions (per month) Recent Major Life Event  \
# ...
