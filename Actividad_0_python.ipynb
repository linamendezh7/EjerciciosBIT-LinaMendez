# %% [markdown]
# <a href="https://colab.research.google.com/github/linamendezh7/EjerciciosBIT-LinaMendez/blob/DataScience/Actividad_0_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print (4.5**2)
# Out:
# 20.25

# %%
print (6000*35)
# Out:
# 210000

# %%
Numero1 = input ("Ingrese numero 1: ")
Numero2 = input ("Ingrese numero 2: ")
Mulpitplicación = int(Numero1)* int(Numero2)
print ("El resultado de la multiplicación es: ",Mulpitplicación)
